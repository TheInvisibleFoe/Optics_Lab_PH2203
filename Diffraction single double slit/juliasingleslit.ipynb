# %%
using Pkg

# %%
using CSV
using DataFrames

# %%
df = DataFrame(CSV.File("csvsingleslit.csv"))
df
# Out:
# 8536×16 DataFrame
#   Row │ Run #2     Run #2_1             Run #2_2     Run #2_3                  ⋯
#       │ String15?  String31?            String15?    String31?                 ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ Time (s)   Light Intensity (%)  Angle (rad)  Angular Velocity (rad/s)  ⋯
#     2 │ 0.000      0.4                  0.000        missing
#     3 │ 0.020      0.4                  0.000        0.000
#     4 │ 0.040      0.4                  0.000        0.000
#     5 │ 0.060      0.4                  0.000        0.000                     ⋯
#     6 │ 0.080      0.4                  0.000        0.000
#     7 │ 0.100      0.4                  0.000        0.000
#     8 │ 0.120      0.4                  0.000        0.000
#     9 │ 0.140      0.4                  0.000        0.000                     ⋯
#    10 │ 0.160      0.4                  0.000        0.000
# ...

# %%
pos1 = df[!,6]
inten1 = df[!,2]
# Out:
# Union{Missing, String15}[String15("Position (m)"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String15("0.0000"), String1
# ...
